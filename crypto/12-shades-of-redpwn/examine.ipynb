# %%
from PIL import Image
import numpy as np

# %%
ls
# Out:
# ciphertext.jpg  color-wheel.jpg  examine.ipynb

# %%
whl = Image.open('color-wheel.jpg', 'r')
txt = Image.open('ciphertext.jpg', 'r')

# %%
txt
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=36500x1500 at 0x7FCFEC414F90>

# %% [markdown]
# Let's number colors from 0 to 12 in clockwise fashion. Then decode each block of 2 colors as a base-12 number, and write them in ASCII for the flag. There's some guessing(?) needed to differentiate b/w some shades, but I am almost sure it can be done without guessing by comparing hex values.

# %%
s = "a3 49 99 43 97 97 41 92 49 7b 41 97 7b 44 92 7b 44 96 98 a5"
flag = "".join(chr(int(c, 12)) for c in s.split())
print(flag)
# Out:
# {9u3ss1n9_1s_4n_4rt}

# %%
whl
# Out:
# <PIL.GifImagePlugin.GifImageFile image mode=P size=436x436 at 0x7FCFF8093850>

# %%
# !ls -l examine.ipynb
# Out:
# -rw-r--r-- 1 me deadpool 300831 Jun 24 19:26 examine.ipynb
